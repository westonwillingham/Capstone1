# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
sns.set_style("whitegrid")

# %%
df = pd.read_csv('drug_consumption.csv')
df.head()
# Out:
#    ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0   1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1   2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2   3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3   4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4   5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
#
#     Oscore   Ascore  ...  Ecstasy  Heroin  Ketamine Legalh  LSD Meth  \
# 0 -0.58331 -0.91699  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 1  1.43533  0.76096  ...      CL4     CL0       CL2    CL0  CL2  CL3
# 2 -0.84732 -1.62090  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 3 -0.01928  0.59042  ...      CL0     CL0       CL2    CL0  CL0  CL0
# 4 -0.45174 -0.30172  ...      CL1     CL0       CL0    CL1  CL0  CL0
#
#   Mushrooms Nicotine Semer  VSA
# 0       CL0      CL2   CL0  CL0
# 1       CL0      CL4   CL0  CL0
# ...

# %%
df.describe()
# Out:
#                 ID         Age       Gender    Education      Country  \
# count  1885.000000  1885.00000  1885.000000  1885.000000  1885.000000
# mean    945.294960     0.03461    -0.000256    -0.003806     0.355542
# std     545.167641     0.87836     0.482588     0.950078     0.700335
# min       1.000000    -0.95197    -0.482460    -2.435910    -0.570090
# 25%     474.000000    -0.95197    -0.482460    -0.611130    -0.570090
# 50%     946.000000    -0.07854    -0.482460    -0.059210     0.960820
# 75%    1417.000000     0.49788     0.482460     0.454680     0.960820
# max    1888.000000     2.59171     0.482460     1.984370     0.960820
#
#          Ethnicity       Nscore       Escore       Oscore       Ascore  \
# count  1885.000000  1885.000000  1885.000000  1885.000000  1885.000000
# mean     -0.309577     0.000047    -0.000163    -0.000534    -0.000245
# std       0.166226     0.998106     0.997448     0.996229     0.997440
# ...

# %%
df.isna().sum()
# Out:
# ID           0
# Age          0
# Gender       0
# Education    0
# Country      0
# Ethnicity    0
# Nscore       0
# Escore       0
# Oscore       0
# Ascore       0
# Cscore       0
# Impulsive    0
# SS           0
# Alcohol      0
# Amphet       0
# Amyl         0
# Benzos       0
# Caff         0
# Cannabis     0
# Choc         0
# Coke         0
# Crack        0
# Ecstasy      0
# Heroin       0
# Ketamine     0
# Legalh       0
# LSD          0
# Meth         0
# Mushrooms    0
# Nicotine     0
# Semer        0
# VSA          0
# dtype: int64

# %%
df.head()
# Out:
#    ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0   1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1   2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2   3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3   4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4   5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
#
#     Oscore   Ascore  ...  Ecstasy  Heroin  Ketamine Legalh  LSD Meth  \
# 0 -0.58331 -0.91699  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 1  1.43533  0.76096  ...      CL4     CL0       CL2    CL0  CL2  CL3
# 2 -0.84732 -1.62090  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 3 -0.01928  0.59042  ...      CL0     CL0       CL2    CL0  CL0  CL0
# 4 -0.45174 -0.30172  ...      CL1     CL0       CL0    CL1  CL0  CL0
#
#   Mushrooms Nicotine Semer  VSA
# 0       CL0      CL2   CL0  CL0
# 1       CL0      CL4   CL0  CL0
# ...

# %%
# columns = ['Alcohol','Amphet', 'Amyl', 'Benzos', 'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack',
#            'Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms','Nicotine', 'Semer', 'VSA']
# fig, axes = plt.subplots(5,3,figsize = (16,16))
# fig.suptitle("Count of Different Classes Vs Drug",fontsize=14)
# k=0
# for i in range(5):
#     for j in range(3):
#         sns.countplot(x=columns[k], data=copy_df,ax=axes[i][j])
#         k+=1

# plt.tight_layout()
# plt.show()

# %%
columns = ['Alcohol','Amphet', 'Amyl', 'Benzos', 'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack',
           'Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms','Nicotine', 'Semer', 'VSA']
fig, axes = plt.subplots(5,3, figsize = (25,25))
fig.suptitle("Count of Different Classes Vs Drug",fontsize=14)
k=0
for i in range(5):
    for j in range(3):
        sns.countplot(x=columns[k], data=df,ax=axes[i][j])
        k+=1

plt.tight_layout()
plt.show()

# %%
columns = ['Mushrooms','Nicotine', 'Semer', 'VSA']
fig, axes = plt.subplots(2,2, figsize = (25,25))
fig.suptitle("Count of Different Classes Vs Drug",fontsize=14)
k=0
for i in range(2):
    for j in range(2):
        sns.countplot(x=columns[k], data=df,ax=axes[i][j])
        k+=1

plt.tight_layout()
plt.show()

# %%
columns = ['Mushrooms','Nicotine', 'Semer', 'VSA']
fig, axes = plt.subplots(figsize = (15,15))
fig.suptitle("Count of Different Classes Vs Drug",fontsize=14)

sns.countplot(x=df["Mushrooms"], data = df)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Frequent Usage Trends
#
# It appears that

# %%
#modifying the dataframes 
newdf = df.copy()
# Out:
#    ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0   1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1   2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2   3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3   4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4   5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
#
#     Oscore   Ascore  ...  Ecstasy  Heroin  Ketamine Legalh  LSD Meth  \
# 0 -0.58331 -0.91699  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 1  1.43533  0.76096  ...      CL4     CL0       CL2    CL0  CL2  CL3
# 2 -0.84732 -1.62090  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 3 -0.01928  0.59042  ...      CL0     CL0       CL2    CL0  CL0  CL0
# 4 -0.45174 -0.30172  ...      CL1     CL0       CL0    CL1  CL0  CL0
#
#   Mushrooms Nicotine Semer  VSA
# 0       CL0      CL2   CL0  CL0
# 1       CL0      CL4   CL0  CL0
# ...

# %%
import seaborn as sns
#sns.heatmap(newdf)
df.head()
# Out:
#    ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0   1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1   2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2   3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3   4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4   5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
#
#     Oscore   Ascore  ...  Ecstasy  Heroin  Ketamine Legalh  LSD Meth  \
# 0 -0.58331 -0.91699  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 1  1.43533  0.76096  ...      CL4     CL0       CL2    CL0  CL2  CL3
# 2 -0.84732 -1.62090  ...      CL0     CL0       CL0    CL0  CL0  CL0
# 3 -0.01928  0.59042  ...      CL0     CL0       CL2    CL0  CL0  CL0
# 4 -0.45174 -0.30172  ...      CL1     CL0       CL0    CL1  CL0  CL0
#
#   Mushrooms Nicotine Semer  VSA
# 0       CL0      CL2   CL0  CL0
# 1       CL0      CL4   CL0  CL0
# ...

# %%
newdf.head()

# dic = {"CL0": 0, 
#       "CL1": 0,
#       "CL2": 0,
#       "CL3": 0,
#       "CL4": 0,
#        "CL5": 0,
       
#       }



#newdf["LSD Freq"] = 
newdf["LSD"].replace('CL0', 0, inplace = True)
newdf["LSD"].replace('CL1', 0.1, inplace = True)
newdf["LSD"].replace('CL2', 0.2, inplace = True)
newdf["LSD"].replace('CL3', 1, inplace = True)
newdf["LSD"].replace('CL4', 12, inplace = True)
newdf["LSD"].replace('CL5', 52, inplace = True)
newdf["LSD"].replace('CL6', 365, inplace = True)
newdf["LSD"].value_counts()
newdf["LSD"].mean()
# Out:
# 4.8256233421750725
