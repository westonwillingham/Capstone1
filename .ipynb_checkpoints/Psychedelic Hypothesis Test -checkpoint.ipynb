# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import scipy.stats as stats

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import scipy.stats as stats
sns.set_style("whitegrid")
df = pd.read_csv('drug_consumption.csv')
#df.head()

# %%
def hasTrippedMushrooms(x):
    if x == "CL0":
        return 0
    else:
        return 1

# %%
df["Tripped Shrooms?"] = df["Mushrooms"].apply(hasTrippedMushrooms)
df["Tripped Shrooms?"].value_counts()
xvals = ["Has Not Done Mushrooms", "Has Done Mushrooms"]
plt.bar(xvals, df["Tripped Shrooms?"].value_counts())
#plt.set_title("Have ")
#df.head()
#
# Out:
# <BarContainer object of 2 artists>

# %%
def hasTrippedLSD(x):
    if x == "CL0":
        return 0
    else:
        return 1 

df["Tripped LSD?"] = df["LSD"].apply(hasTrippedLSD)
df["Tripped LSD?"].value_counts()
xvals = ["Has Not Done LSD", "Has Done LSD"]

plt.bar(xvals, df["Tripped LSD?"].value_counts())
df["Tripped LSD?"].value_counts()
#plt.set_title("Have ")
#df.head()
#
# Out:
# 0    1069
# 1     816
# Name: Tripped LSD?, dtype: int64

# %% [markdown]
# # Insight
# More people have done mushrooms than LSD before

# %%
def hasTripped(x):
    if x == "CL0":
        return 0
    else:
        return 1 
def isolate(x): 
    if x == 1 or x ==2: 
        return 1 
    else: 
        return 0 
    
df["Tripped?"] = df["Tripped Shrooms?"] + df["Tripped LSD?"] 
df["Tripped?"] = df["Tripped?"].apply(isolate)

df["Tripped?"].value_counts()
xvals = ["Has Tripped", "Has Not Tripped"]

plt.pie(df["Tripped?"].value_counts(), labels = xvals, autopct='%1.1f%%');

#df["Tripped?"].value_counts()
#plt.set_title("Have ")
#df.head()
#

# %%
def hasTripped(x):
    if x == "CL0":
        return 0
    else:
        return 1 

df["Tripped on how many?"] = df["Tripped Shrooms?"] + df["Tripped LSD?"] 
df["Tripped on how many?"].value_counts()
xvals = ["Has Not Done Either", "Has Done Both", "Has Done One"]

plt.pie(df["Tripped on how many?"].value_counts(), labels = xvals,autopct='%1.1f%%')
df["Tripped on how many?"].value_counts()
#plt.set_title("Have ")
#df.head()
#
# Out:
# 0    860
# 2    694
# 1    331
# Name: Tripped on how many?, dtype: int64

# %%
print("Openness Score of People Who Have Tripped At Least Once")
df[df["Tripped?"] == 1]['Oscore'].mean()
# Out:
# Openness Score of People Who Have Tripped At Least Once
# 0.32966835121951293

# %%
print("Openness Score of People Who Have Never Tripped")
df[df["Tripped?"] == 0]['Oscore'].mean()
# Out:
# Openness Score of People Who Have Never Tripped
# -0.3940899999999987

# %%
print("Mean Openness Score")
df['Oscore'].mean()
# Out:
# Mean Openness Score
# -0.0005343978779841072

# %%
df[df["Tripped?"] == 1][:].mean() - df[:].mean()
# Out:
# ID                      67.960650
# Age                     -0.131762
# Gender                  -0.116947
# Education               -0.127260
# Country                 -0.294313
# Ethnicity                0.018305
# Nscore                   0.064918
# Escore                  -0.025451
# Oscore                   0.330203
# Ascore                  -0.127552
# Cscore                  -0.194383
# Impulsive                0.248598
# SS                       0.336065
# Tripped Shrooms?         0.401931
# Tripped LSD?             0.363206
# Tripped?                 0.456233
# Tripped on how many?     0.765137
# dtype: float64

# %% [markdown]
# # Affect of Tripping
# It seems that the average openness of a psychedelic user is much higher than any other category

# %%
np.std(df[df["Tripped?"] == 1]['Oscore'])
# Out:
# 0.940645544042255

# %%
fig, ax = plt.subplots()
ax = plt.hist(df[df["Tripped?"] == 1]['Oscore'])

# %%
plt.hist(df[df["Tripped?"] == 0]['Oscore'])
# Out:
# (array([  5.,  16.,  56., 129., 231., 210., 136.,  47.,  20.,  10.]),
#  array([-3.27393 , -2.701633, -2.129336, -1.557039, -0.984742, -0.412445,
#          0.159852,  0.732149,  1.304446,  1.876743,  2.44904 ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Psychedelic Openness Hypothesis Testing

# %% [markdown]
# Null Hypothesis H0: that the mean openness for non-psychedelic users = the mean openness for psychedelic users
# Ha: Psych users are more open

# %%
var0 = (np.var(df[df["Tripped?"] == 0]['Oscore']))/len(df[df["Tripped?"] == 0]['Oscore'])
var1 = (np.var(df[df["Tripped?"] == 1]['Oscore']))/len(df[df["Tripped?"] == 1]['Oscore'])

shared_sample_variance = var0 + var1
#print(shared_sample_variance)
diff_in_Oscore = stats.norm(0, np.sqrt(shared_sample_variance))

# %%
# fig, ax = plt.subplots(1, figsize=(16, 3))

# x = np.linspace(-0.25, 0.75, num=250)
# ax.plot(x, diff_in_Oscore.pdf(x), linewidth=3)
# ax.set_xlim(-0.25, 0.75)
# ax.axvline(mean_diff)

# ax.set_title("Distribution of Difference in Sample Frequencies Assuming $H_0$");

# %%
𝛼 = 0.05
x = np.linspace(-3, 3, num=2500)
threshold = diff_in_Oscore.ppf(1-𝛼)

fig, ax = plt.subplots(1, figsize=(16, 3))

ax.plot(x, diff_in_Oscore.pdf(x), linewidth=3)
ax.axvline(threshold)
ax.set_xlim(-0.2, 0.20)
ax.fill_between(x, 0, diff_in_Oscore.pdf(x), x>threshold, color = 'blue')
ax.set_title(f'{100*𝛼}% of the area under the curve falls to the right of {round(threshold,3)}');

# %%
mean_diff = df[df["Tripped?"] == 1]['Oscore'].mean() - df[df["Tripped?"] == 0]['Oscore'].mean()
mean_diff
# Out:
# 0.7237583512195116

# %%
p_value = 1 - diff_in_Oscore.cdf(mean_diff)
p_value 
#print("p-value for openness comparison: {:2.3f}".format(p_value))
# Out:
# 0.0

# %%
tdiff_in_Oscore = stats.ttest_ind(df[df["Tripped?"] == 1]['Oscore'], df[df["Tripped?"] == 0]['Oscore'])
tdiff_in_Oscore[1]
# Out:
# 1.9383924863049046e-59

# %%
tdiff_in_Oscore = stats.ttest_ind(df[df["Tripped?"] == 1]['Impulsive'], df[df["Tripped?"] == 0]['Impulsive'])
tdiff_in_Oscore[1]
# Out:
# 2.056089514730359e-36

# %%
tdiff_in_Oscore = stats.ttest_ind(df[df["Tripped?"] == 1]['SS'], df[df["Tripped?"] == 0]['SS'])
tdiff_in_Oscore[1]
# Out:
# 4.175824191309417e-66

# %%
tdiff_in_Oscore = stats.ttest_ind(df[df["Tripped?"] == 1]['Ascore'], df[df["Tripped?"] == 0]['Ascore'])
tdiff_in_Oscore[1]
# Out:
# 1.1376640083766759e-09

# %%
tdiff_in_Oscore = stats.ttest_ind(df[df["Tripped?"] == 1]['Cscore'], df[df["Tripped?"] == 0]['Cscore'])
tdiff_in_Oscore[1]
# Out:
# 9.643005652650709e-21

# %%
tdiff_in_Oscore = stats.ttest_ind(df[df["Tripped?"] == 1]['Nscore'], df[df["Tripped?"] == 0]['Nscore'])
tdiff_in_Oscore[1]
# Out:
# 0.0020318443361281636

# %%
tdiff_in_Oscore = stats.ttest_ind(df[df["Tripped?"] == 1]['Escore'], df[df["Tripped?"] == 0]['Escore'])
tdiff_in_Oscore[1]
# Out:
# 0.22658702433064598

# %%
df[df["Tripped?"] == 1][:].mean() - df[:].mean()
df.head
# Out:
# <bound method NDFrame.head of         ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0        1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1        2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2        3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3        4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4        5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
# 5        6  2.59171  0.48246   -1.22751  0.24923   -0.31685 -0.67825 -0.30033
# 6        7  1.09449 -0.48246    1.16365 -0.57009   -0.31685 -0.46725 -1.09207
# 7        8  0.49788 -0.48246   -1.73790  0.96082   -0.31685 -1.32828  1.93886
# 8        9  0.49788  0.48246   -0.05921  0.24923   -0.31685  0.62967  2.57309
# 9       10  1.82213 -0.48246    1.16365  0.96082   -0.31685 -0.24649  0.00332
# 10      11 -0.07854  0.48246    0.45468  0.96082   -0.31685 -1.05308  0.80523
# 11      12  1.09449 -0.48246   -0.61113 -0.28519   -0.31685 -1.32828  0.00332
# 12      13  1.82213  0.48246    0.45468  0.96082   -0.31685  2.28554  0.16767
# 13      14  1.82213  0.48246   -0.05921  0.24923   -0.31685 -0.79151  0.80523
# 14      15  1.82213  0.48246   -0.05921  0.96082   -0.31685 -0.92104  1.45421
# 15      16  1.82213 -0.48246    0.45468  0.96082   -0.31685 -2.05048 -1.50796
# 16      17  0.49788  0.48246   -0.61113  0.96082   -0.31685 -1.55078 -0.80615
# 17      18  1.09449 -0.48246   -1.73790  0.96082   -0.31685  0.52135 -1.23177
# 18      19  1.82213 -0.48246    0.45468 -0.09765   -0.31685  1.37297 -0.15487
# 19      20  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.34799 -1.76250
# 20      21  1.09449 -0.48246   -0.05921  0.96082   -0.31685 -0.79151  0.80523
# 21      22  2.59171 -0.48246   -2.43591  0.96082   -0.31685 -1.19430  0.47617
# 22      23  1.09449 -0.48246    0.45468  0.96082   -0.31685  0.41667 -0.94779
# 23      24  1.09449 -0.48246   -1.73790  0.96082   -0.31685  1.60383 -3.27393
# 24      25  1.82213 -0.48246    0.45468  0.96082   -0.31685 -0.14882  0.63779
# 25      26  1.09449 -0.48246   -0.61113  0.96082   -0.31685 -0.79151 -0.43999
# 26      27  1.82213  0.48246   -1.22751  0.24923   -0.31685 -0.05188 -1.63340
# 27      28  0.49788 -0.48246    0.45468  0.96082   -0.31685  0.52135 -1.23177
# 28      29  0.49788  0.48246    1.16365  0.96082   -0.31685  0.04257 -1.50796
# 29      30  1.09449 -0.48246    1.98437  0.96082   -0.31685 -1.32828  1.74091
# ...    ...      ...      ...        ...      ...        ...      ...      ...
# 1855  1859  0.49788 -0.48246   -0.05921 -0.28519   -0.31685 -1.19430  1.11406
# 1856  1860 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685  0.31287 -0.57545
# 1857  1861 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685  1.72012  0.32197
# 1858  1862 -0.95197 -0.48246   -1.22751 -0.57009   -0.31685 -0.24649  0.32197
# 1859  1863  0.49788 -0.48246   -0.61113 -0.28519   -0.31685 -0.34799  0.00332
# 1860  1864  1.82213  0.48246    0.45468  0.24923   -0.31685 -1.69163 -1.09207
# 1861  1865 -0.07854  0.48246    0.45468 -0.57009    0.11440 -0.34799  0.00332
# 1862  1866  1.09449 -0.48246   -2.43591 -0.57009   -0.31685  0.73545 -0.43999
# 1863  1867 -0.95197  0.48246   -0.61113 -0.57009   -0.31685  0.62967  0.63779
# 1864  1868 -0.07854 -0.48246   -0.61113 -0.57009   -0.31685 -2.05048  0.00332
# 1865  1869 -0.95197  0.48246   -0.05921 -0.57009   -0.31685  0.04257  0.00332
# 1866  1870 -0.95197  0.48246    0.45468 -0.57009   -0.31685  0.13606 -0.80615
# 1867  1871 -0.95197  0.48246   -0.61113 -0.57009   -0.31685  1.13281 -0.43999
# 1868  1872 -0.95197 -0.48246   -0.61113 -0.28519   -0.31685 -0.58016 -0.15487
# 1869  1873 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685 -0.14882  1.11406
# 1870  1874 -0.07854  0.48246    0.45468 -0.28519   -0.31685 -1.05308  0.96248
# 1871  1875 -0.95197 -0.48246   -1.22751 -0.57009   -0.31685  1.02119 -0.43999
# 1872  1876 -0.95197 -0.48246   -0.61113  0.24923   -0.31685 -0.79151  0.00332
# 1873  1877 -0.95197 -0.48246   -1.43719 -0.57009   -0.31685  0.73545 -1.23177
# 1874  1878  2.59171 -0.48246   -0.61113 -0.57009   -0.31685  2.12700 -0.15487
# 1875  1879 -0.95197 -0.48246   -0.61113 -0.57009    0.12600 -0.05188 -1.76250
# 1876  1880 -0.07854 -0.48246   -0.61113  0.24923    0.11440 -0.14882 -0.57545
# 1877  1881 -0.95197 -0.48246   -1.43719 -0.57009   -0.31685  1.49158 -1.92173
# 1878  1882 -0.95197 -0.48246    0.45468  0.24923   -0.31685 -0.05188 -1.76250
# 1879  1883 -0.95197 -0.48246   -0.61113 -0.28519   -0.31685 -0.79151  0.32197
# 1880  1884 -0.95197  0.48246   -0.61113 -0.57009   -0.31685 -1.19430  1.74091
# 1881  1885 -0.95197 -0.48246   -0.61113 -0.57009   -0.31685 -0.24649  1.74091
# 1882  1886 -0.07854  0.48246    0.45468 -0.57009   -0.31685  1.13281 -1.37639
# 1883  1887 -0.95197  0.48246   -0.61113 -0.57009   -0.31685  0.91093 -1.92173
# 1884  1888 -0.95197 -0.48246   -0.61113  0.21128   -0.31685 -0.46725  2.12700
#
#        Oscore   Ascore  ...  LSD  Meth  Mushrooms Nicotine Semer  VSA  \
# 0    -0.58331 -0.91699  ...  CL0   CL0        CL0      CL2   CL0  CL0
# 1     1.43533  0.76096  ...  CL2   CL3        CL0      CL4   CL0  CL0
# 2    -0.84732 -1.62090  ...  CL0   CL0        CL1      CL0   CL0  CL0
# 3    -0.01928  0.59042  ...  CL0   CL0        CL0      CL2   CL0  CL0
# 4    -0.45174 -0.30172  ...  CL0   CL0        CL2      CL2   CL0  CL0
# 5    -1.55521  2.03972  ...  CL0   CL0        CL0      CL6   CL0  CL0
# 6    -0.45174 -0.30172  ...  CL0   CL0        CL0      CL6   CL0  CL0
# 7    -0.84732 -0.30172  ...  CL0   CL0        CL0      CL0   CL0  CL0
# 8    -0.97631  0.76096  ...  CL0   CL0        CL0      CL6   CL0  CL0
# 9    -1.42424  0.59042  ...  CL0   CL0        CL0      CL6   CL0  CL0
# 10   -1.11902 -0.76096  ...  CL0   CL0        CL0      CL2   CL0  CL1
# 11    0.14143 -1.92595  ...  CL1   CL0        CL2      CL6   CL0  CL0
# 12    0.44585 -1.62090  ...  CL1   CL1        CL1      CL6   CL0  CL0
# 13   -0.01928  0.94156  ...  CL0   CL0        CL0      CL1   CL0  CL0
# 14    0.44585 -0.60633  ...  CL0   CL0        CL0      CL6   CL0  CL0
# 15   -1.55521 -1.07533  ...  CL0   CL0        CL0      CL0   CL0  CL0
# 16   -1.68062  0.28783  ...  CL0   CL0        CL0      CL6   CL0  CL0
# 17   -0.31776 -0.45321  ...  CL1   CL0        CL1      CL6   CL0  CL0
# 18   -0.17779 -1.92595  ...  CL1   CL0        CL1      CL0   CL0  CL0
# 19   -2.39883 -1.92595  ...  CL0   CL6        CL0      CL1   CL0  CL0
# 20    0.72330  1.61108  ...  CL1   CL0        CL1      CL3   CL0  CL0
# 21   -1.11902 -0.60633  ...  CL0   CL0        CL1      CL1   CL0  CL0
# 22   -0.84732  1.11406  ...  CL0   CL0        CL0      CL0   CL0  CL0
# 23   -1.27553  0.28783  ...  CL1   CL0        CL0      CL6   CL0  CL1
# 24    1.24033  0.76096  ...  CL1   CL0        CL1      CL6   CL0  CL0
# 25   -1.27553  0.94156  ...  CL2   CL0        CL2      CL1   CL0  CL0
# 26   -3.27393 -0.76096  ...  CL0   CL0        CL0      CL6   CL0  CL0
# 27   -0.01928 -0.01729  ...  CL1   CL0        CL3      CL2   CL0  CL0
# 28   -0.71727  0.28783  ...  CL0   CL0        CL0      CL0   CL0  CL0
# 29    0.88309  0.94156  ...  CL0   CL0        CL0      CL0   CL0  CL0
# ...       ...      ...  ...  ...   ...        ...      ...   ...  ...
# 1855  0.58331 -0.01729  ...  CL4   CL0        CL5      CL2   CL0  CL0
# 1856 -0.31776 -1.47955  ...  CL3   CL0        CL0      CL4   CL0  CL2
# 1857  1.65653 -0.15487  ...  CL2   CL4        CL3      CL3   CL0  CL2
# 1858  0.44585 -0.15487  ...  CL6   CL4        CL5      CL6   CL0  CL0
# 1859  0.72330  0.28783  ...  CL4   CL2        CL4      CL6   CL0  CL1
# 1860  1.06238 -0.45321  ...  CL1   CL6        CL2      CL2   CL0  CL0
# 1861  1.24033 -0.15487  ...  CL0   CL4        CL2      CL4   CL0  CL0
# 1862  0.44585 -1.07533  ...  CL1   CL5        CL1      CL6   CL0  CL0
# 1863  2.90161 -1.07533  ...  CL4   CL3        CL4      CL5   CL0  CL0
# 1864  2.15324 -0.91699  ...  CL6   CL0        CL4      CL6   CL0  CL2
# 1865  2.44904 -0.60633  ...  CL3   CL3        CL3      CL6   CL0  CL1
# 1866  1.43533  0.28783  ...  CL3   CL0        CL3      CL4   CL0  CL0
# 1867  0.29338 -0.76096  ...  CL2   CL0        CL2      CL6   CL0  CL0
# 1868  0.29338 -1.62090  ...  CL0   CL0        CL4      CL6   CL0  CL0
# 1869  1.43533 -0.30172  ...  CL3   CL4        CL3      CL4   CL0  CL0
# 1870  1.88511  1.81866  ...  CL3   CL0        CL1      CL5   CL0  CL0
# 1871  1.43533 -1.07533  ...  CL3   CL3        CL0      CL6   CL0  CL6
# 1872  2.44904  0.76096  ...  CL0   CL0        CL0      CL0   CL0  CL0
# 1873  0.58331 -0.60633  ...  CL2   CL2        CL3      CL6   CL0  CL2
# 1874  2.44904  0.94156  ...  CL1   CL0        CL1      CL0   CL0  CL0
# 1875  0.58331 -0.76096  ...  CL4   CL0        CL4      CL6   CL0  CL2
# 1876  1.43533 -0.91699  ...  CL3   CL0        CL4      CL2   CL0  CL2
# 1877 -0.58331 -1.77200  ...  CL0   CL6        CL0      CL6   CL0  CL2
# 1878  0.88309 -0.76096  ...  CL0   CL0        CL2      CL2   CL0  CL0
# 1879  0.29338 -0.30172  ...  CL5   CL4        CL0      CL6   CL0  CL1
# 1880  1.88511  0.76096  ...  CL3   CL0        CL0      CL0   CL0  CL5
# 1881  0.58331  0.76096  ...  CL5   CL4        CL4      CL5   CL0  CL0
# 1882 -1.27553 -1.77200  ...  CL2   CL0        CL2      CL6   CL0  CL0
# 1883  0.29338 -1.62090  ...  CL3   CL0        CL3      CL4   CL0  CL0
# 1884  1.65653  1.11406  ...  CL3   CL0        CL3      CL6   CL0  CL2
#
#      Tripped Shrooms? Tripped LSD? Tripped? Tripped on how many?
# 0                   0            0        0                    0
# 1                   0            1        1                    1
# 2                   1            0        1                    1
# 3                   0            0        0                    0
# 4                   1            0        1                    1
# 5                   0            0        0                    0
# 6                   0            0        0                    0
# 7                   0            0        0                    0
# 8                   0            0        0                    0
# 9                   0            0        0                    0
# 10                  0            0        0                    0
# 11                  1            1        1                    2
# 12                  1            1        1                    2
# 13                  0            0        0                    0
# 14                  0            0        0                    0
# 15                  0            0        0                    0
# 16                  0            0        0                    0
# 17                  1            1        1                    2
# 18                  1            1        1                    2
# 19                  0            0        0                    0
# 20                  1            1        1                    2
# 21                  1            0        1                    1
# 22                  0            0        0                    0
# 23                  0            1        1                    1
# 24                  1            1        1                    2
# 25                  1            1        1                    2
# 26                  0            0        0                    0
# 27                  1            1        1                    2
# 28                  0            0        0                    0
# 29                  0            0        0                    0
# ...               ...          ...      ...                  ...
# 1855                1            1        1                    2
# 1856                0            1        1                    1
# 1857                1            1        1                    2
# 1858                1            1        1                    2
# 1859                1            1        1                    2
# 1860                1            1        1                    2
# 1861                1            0        1                    1
# 1862                1            1        1                    2
# 1863                1            1        1                    2
# 1864                1            1        1                    2
# 1865                1            1        1                    2
# 1866                1            1        1                    2
# 1867                1            1        1                    2
# 1868                1            0        1                    1
# 1869                1            1        1                    2
# 1870                1            1        1                    2
# 1871                0            1        1                    1
# 1872                0            0        0                    0
# 1873                1            1        1                    2
# 1874                1            1        1                    2
# 1875                1            1        1                    2
# 1876                1            1        1                    2
# 1877                0            0        0                    0
# 1878                1            0        1                    1
# 1879                0            1        1                    1
# 1880                0            1        1                    1
# 1881                1            1        1                    2
# 1882                1            1        1                    2
# 1883                1            1        1                    2
# 1884                1            1        1                    2
#
# [1885 rows x 36 columns]>
