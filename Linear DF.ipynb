# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns 
import scipy.stats as stats
sns.set_style("whitegrid")
#df = pd.read_csv('drug_consumption.csv')
#df.head()
# %matplotlib inline

# %%
df = pd.read_csv('drug_consumption.csv')
def changeRate(x):
    if x == "CL0":
        return 0 
    elif x == "CL1":
        return 0.05
    elif x == "CL2":
        return 0.1
    elif x == "CL3":
        return 1
    elif x == "CL4":
        return 12
    elif x == "CL5":
        return 52
    elif x == "CL6":
        return 365

columns = ['Alcohol','Amphet', 'Amyl', 'Benzos', 'Caff', 'Cannabis', 'Choc', 'Coke', 'Crack',
           'Ecstasy', 'Heroin', 'Ketamine', 'Legalh', 'LSD', 'Meth', 'Mushrooms','Nicotine', 'Semer', 'VSA']
    
for col in columns:
    df[col] = df[col].apply(changeRate)
#f["Alcohol"] = df["Alcohol"].apply(changeRate)

df.head()
#df["Alcohol"].value_counts()
#df.to_csv("linear_drug_consumption.csv")
# Out:
#    ID      Age   Gender  Education  Country  Ethnicity   Nscore   Escore  \
# 0   1  0.49788  0.48246   -0.05921  0.96082    0.12600  0.31287 -0.57545
# 1   2 -0.07854 -0.48246    1.98437  0.96082   -0.31685 -0.67825  1.93886
# 2   3  0.49788 -0.48246   -0.05921  0.96082   -0.31685 -0.46725  0.80523
# 3   4 -0.95197  0.48246    1.16365  0.96082   -0.31685 -0.14882 -0.80615
# 4   5  0.49788  0.48246    1.98437  0.96082   -0.31685  0.73545 -1.63340
#
#     Oscore   Ascore  ...  Ecstasy  Heroin  Ketamine  Legalh  LSD  Meth  \
# 0 -0.58331 -0.91699  ...     0.00     0.0       0.0    0.00  0.0   0.0
# 1  1.43533  0.76096  ...    12.00     0.0       0.1    0.00  0.1   1.0
# 2 -0.84732 -1.62090  ...     0.00     0.0       0.0    0.00  0.0   0.0
# 3 -0.01928  0.59042  ...     0.00     0.0       0.1    0.00  0.0   0.0
# 4 -0.45174 -0.30172  ...     0.05     0.0       0.0    0.05  0.0   0.0
#
#    Mushrooms  Nicotine  Semer  VSA
# 0       0.00       0.1    0.0  0.0
# ...

# %%
#f.drop(labels = ['ID', "Age", "Gender", "Country", "Ethnicity"], axis = 1, inplace = True)
df.head()
# Out:
#    Education   Nscore   Escore   Oscore   Ascore   Cscore  Impulsive       SS  \
# 0   -0.05921  0.31287 -0.57545 -0.58331 -0.91699 -0.00665   -0.21712 -1.18084
# 1    1.98437 -0.67825  1.93886  1.43533  0.76096 -0.14277   -0.71126 -0.21575
# 2   -0.05921 -0.46725  0.80523 -0.84732 -1.62090 -1.01450   -1.37983  0.40148
# 3    1.16365 -0.14882 -0.80615 -0.01928  0.59042  0.58489   -1.37983 -1.18084
# 4    1.98437  0.73545 -1.63340 -0.45174 -0.30172  1.30612   -0.21712 -0.21575
#
#    Alcohol  Amphet  ...  Ecstasy  Heroin  Ketamine  Legalh  LSD  Meth  \
# 0     52.0    0.10  ...     0.00     0.0       0.0    0.00  0.0   0.0
# 1     52.0    0.10  ...    12.00     0.0       0.1    0.00  0.1   1.0
# 2    365.0    0.00  ...     0.00     0.0       0.0    0.00  0.0   0.0
# 3     12.0    0.00  ...     0.00     0.0       0.1    0.00  0.0   0.0
# 4     12.0    0.05  ...     0.05     0.0       0.0    0.05  0.0   0.0
#
#    Mushrooms  Nicotine  Semer  VSA
# 0       0.00       0.1    0.0  0.0
# ...

# %%
sns.jointplot(x='Alcohol',y='Education',data=df,kind='reg')

# %%
for col in columns:
    print(col+" Openness Correlation")
    print(round(stats.pearsonr(df[col], df["Oscore"])[0],3))
# Out:
# Alcohol Openness Correlation
# 0.022
# Amphet Openness Correlation
# 0.06
# Amyl Openness Correlation
# -0.01
# Benzos Openness Correlation
# 0.066
# Caff Openness Correlation
# -0.024
# Cannabis Openness Correlation
# 0.297
# Choc Openness Correlation
# -0.019
# Coke Openness Correlation
# 0.007
# Crack Openness Correlation
# -0.02
# Ecstasy Openness Correlation
# 0.076
# Heroin Openness Correlation
# 0.027
# Ketamine Openness Correlation
# 0.061
# Legalh Openness Correlation
# 0.061
# LSD Openness Correlation
# 0.146
# Meth Openness Correlation
# 0.024
# Mushrooms Openness Correlation
# 0.113
# Nicotine Openness Correlation
# 0.101
# Semer Openness Correlation
# 0.007
# VSA Openness Correlation
# 0.049

# %%
import seaborn as sns
import scipy.stats as stats

#sns.set(style="darkgrid", color_codes=True)
j = sns.jointplot(x='Mushrooms',y='Oscore',data=df,kind='reg')
j.annotate(stats.pearsonr)
plt.show()
# Out:
# /home/weston/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
import seaborn as sns
import scipy.stats as stats

#sns.set(style="darkgrid", color_codes=True)
j = sns.jointplot(x='Mushrooms',y='Oscore',data=df,kind='reg')
j.annotate(stats.pearsonr)
plt.show()
# Out:
# /home/weston/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
import seaborn as sns
import scipy.stats as stats

#sns.set(style="darkgrid", color_codes=True)
j = sns.jointplot(x='Alcohol',y='Education',data=df,kind='reg')
j.annotate(stats.pearsonr)
plt.show()
# Out:
# /home/weston/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
import seaborn as sns
import scipy.stats as stats

#sns.set(style="darkgrid", color_codes=True)
j = sns.jointplot(x='LSD',y='Nscore',data=df,kind='reg')
j.annotate(stats.pearsonr)
plt.show()
# Out:
# /home/weston/anaconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:1847: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %%
values = []
for col in columns:
    values.append((stats.pearsonr(df[col], df["Oscore"])[0]))

fig, ax = plt.subplots(figsize = (10,10))
plt.plot(columns, values)
